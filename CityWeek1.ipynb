# %% [markdown]
# # In what major TX City (Dallas, Houston, Austin, San Antonio) should you open a business and what type of business should it be?
#
# #### In this project, we will analyze major Texas Cities to discover a lack of a certain type of business in one of the city to decide whether we should open a business of that type there or not.

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Create list of TX Cities

# %%
tx_cities_df = pd.DataFrame({'city': ['Austin','Dallas','Houston','San Antonio'],
                             'lats': [30.2672, 32.7767, 29.7604, 29.4241],
                             'lons': [-97.7431, -96.7970, -95.3698, -98.4936]})

# %%
tx_cities_df
# Out:
#           city     lats     lons
# 0       Austin  30.2672 -97.7431
# 1       Dallas  32.7767 -96.7970
# 2      Houston  29.7604 -95.3698
# 3  San Antonio  29.4241 -98.4936

# %% [markdown]
# ### Foursquare API Information

# %%
CLIENT_ID = 'WPVYKKSG3BEGIX5T3QFJOPTURIVR0FIT40RSZF0R42OMRCGE' # your Foursquare ID
CLIENT_SECRET = 'BQ5U2MDOBZ5D5VYXODXQCGDYLY0IIPOCN45LNOSLVLXPFCJQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 500 # A default Foursquare API limit value

# %% [markdown]
# ## Get venues for each city

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius,
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City', 
                  'City Latitude', 
                  'City Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
city_venues = getNearbyVenues(names=tx_cities_df['city'],
                               latitudes=tx_cities_df['lats'],
                               longitudes=tx_cities_df['lons'])

print('getNearbyVenues Done')
# Out:
# Austin
# Dallas
# Houston
# San Antonio
# getNearbyVenues Done

# %%
# Createing back up to not run API if need a fresh data frame

city_backup = city_venues[:]

# %%
city_venues.head()
# Out:
#      City  City Latitude  City Longitude                           Venue  \
# 0  Austin        30.2672        -97.7431  Truluck's Seafood Steak & Crab
# 1  Austin        30.2672        -97.7431            Upstairs at Caroline
# 2  Austin        30.2672        -97.7431                    The Driskill
# 3  Austin        30.2672        -97.7431     Firehouse Hostel and Lounge
# 4  Austin        30.2672        -97.7431                       JuiceLand
#
#    Venue Latitude  Venue Longitude      Venue Category
# 0       30.266757       -97.744968  Seafood Restaurant
# 1       30.268810       -97.742310               Hotel
# 2       30.267841       -97.741715               Hotel
# 3       30.268096       -97.741283              Lounge
# 4       30.266037       -97.742623           Juice Bar

# %% [markdown]
# ## Check how many venues the API pulled for each city

# %%
city_venues[['City', 'Venue']].groupby('City').count()
# Out:
#              Venue
# City
# Austin         100
# Dallas          26
# Houston         61
# San Antonio    100

# %%
# Check unique categories
print('There are {} unique categories'.format(city_venues['Venue Category'].nunique()))
# Out:
# There are 104 unique categories

# %% [markdown]
# ## Let's encode the categories for each city

# %%
# one hot encoding
city_onehot = pd.get_dummies(city_venues[['Venue Category']], prefix="", prefix_sep="")
# add city column back to dataframe
city_onehot['City'] = city_venues['City'] 

# move city column to the first column
fixed_columns = [city_onehot.columns[city_onehot.columns.get_loc('City')]] + list(city_onehot.loc[:, city_onehot.columns != 'City'].columns)
city_onehot = city_onehot[fixed_columns]

# group cities together and get their weighted average score for each Venue
city_grouped = city_onehot.groupby('City').mean().reset_index()

city_grouped.head()
# Out:
#           City  Airport Service  American Restaurant  Aquarium  Art Gallery  \
# 0       Austin         0.000000             0.010000  0.000000         0.00
# 1       Dallas         0.000000             0.038462  0.000000         0.00
# 2      Houston         0.016393             0.016393  0.016393         0.00
# 3  San Antonio         0.000000             0.040000  0.000000         0.01
#
#    Art Museum  BBQ Joint  Bagel Shop  Bakery   Bar  Beer Bar    Bistro  \
# 0        0.00   0.010000    0.000000    0.00  0.06      0.01  0.000000
# 1        0.00   0.000000    0.000000    0.00  0.00      0.00  0.038462
# 2        0.00   0.016393    0.016393    0.00  0.00      0.00  0.000000
# 3        0.01   0.000000    0.000000    0.01  0.03      0.00  0.000000
#
#    Boutique  Breakfast Spot  Bridge  Burger Joint      Café  \
# 0  0.000000            0.01    0.00      0.010000  0.010000
# 1  0.038462            0.00    0.00      0.038462  0.038462
# 2  0.000000            0.00    0.00      0.049180  0.000000
# 3  0.000000            0.00    0.01      0.020000  0.000000
#
#    Cajun / Creole Restaurant  Chinese Restaurant  Church  Churrascaria  \
# 0                       0.01                0.01    0.00          0.01
# 1                       0.00                0.00    0.00          0.00
# 2                       0.00                0.00    0.00          0.00
# 3                       0.00                0.00    0.01          0.00
#
#    Clothing Store  Cocktail Bar  Coffee Shop  Concert Hall  Convenience Store  \
# 0            0.01          0.05     0.060000      0.010000               0.00
# 1            0.00          0.00     0.076923      0.000000               0.00
# 2            0.00          0.00     0.065574      0.032787               0.00
# 3            0.00          0.06     0.030000      0.000000               0.01
#
#    Cycle Studio  Deli / Bodega  Department Store  Dessert Shop  \
# 0          0.01       0.000000          0.000000          0.01
# 1          0.00       0.000000          0.038462          0.00
# 2          0.00       0.016393          0.000000          0.00
# 3          0.00       0.000000          0.000000          0.00
#
#    Discount Store  Donut Shop  Empanada Restaurant  Farmers Market  \
# 0            0.00        0.01             0.000000        0.010000
# 1            0.00        0.00             0.000000        0.000000
# 2            0.00        0.00             0.016393        0.016393
# 3            0.01        0.00             0.000000        0.000000
#
#    Fast Food Restaurant  Food Court  Food Service  Food Truck  \
# 0              0.000000    0.010000      0.000000        0.03
# 1              0.000000    0.000000      0.000000        0.00
# 2              0.016393    0.016393      0.016393        0.00
# 3              0.000000    0.000000      0.000000        0.00
#
#    French Restaurant  Fried Chicken Joint  Furniture / Home Store  Gay Bar  \
# 0           0.010000             0.010000                0.000000     0.04
# 1           0.038462             0.000000                0.038462     0.00
# 2           0.000000             0.016393                0.000000     0.00
# 3           0.000000             0.000000                0.000000     0.00
#
#    Gift Shop  Greek Restaurant  Grocery Store       Gym  Historic Site  \
# 0       0.01              0.00       0.000000  0.010000           0.00
# 1       0.00              0.00       0.038462  0.000000           0.00
# 2       0.00              0.00       0.000000  0.016393           0.00
# 3       0.00              0.01       0.000000  0.000000           0.01
#
#    History Museum     Hotel  Hotel Bar  Ice Cream Shop  Indian Restaurant  \
# 0            0.00  0.090000   0.020000            0.00           0.000000
# 1            0.00  0.269231   0.000000            0.00           0.038462
# 2            0.00  0.049180   0.016393            0.00           0.000000
# 3            0.01  0.150000   0.000000            0.03           0.000000
#
#    Intersection  Israeli Restaurant  Italian Restaurant  Japanese Restaurant  \
# 0      0.000000                0.01            0.020000             0.000000
# 1      0.000000                0.00            0.000000             0.000000
# 2      0.016393                0.00            0.016393             0.016393
# 3      0.000000                0.00            0.020000             0.000000
#
#    Jazz Club  Juice Bar  Latin American Restaurant    Lounge  \
# 0       0.01       0.02                       0.01  0.030000
# 1       0.00       0.00                       0.00  0.000000
# 2       0.00       0.00                       0.00  0.016393
# 3       0.00       0.00                       0.00  0.030000
#
#    Mediterranean Restaurant  Men's Store  Mexican Restaurant  \
# 0                  0.010000         0.01            0.020000
# 1                  0.000000         0.00            0.038462
# 2                  0.032787         0.00            0.000000
# 3                  0.010000         0.01            0.100000
#
#    Mobile Phone Shop  Motorcycle Shop  Movie Theater  Museum  Music Venue  \
# 0           0.000000             0.00       0.020000    0.01     0.020000
# 1           0.038462             0.00       0.000000    0.00     0.000000
# 2           0.000000             0.00       0.016393    0.00     0.016393
# 3           0.000000             0.01       0.000000    0.00     0.000000
#
#    Neighborhood  New American Restaurant  Nightclub  Outdoors & Recreation  \
# 0          0.00                 0.020000       0.01               0.000000
# 1          0.00                 0.038462       0.00               0.000000
# 2          0.00                 0.000000       0.00               0.016393
# 3          0.01                 0.010000       0.01               0.000000
#
#        Park  Pedestrian Plaza  Performing Arts Venue  Pharmacy  Piano Bar  \
# 0  0.010000              0.00               0.010000      0.00       0.01
# 1  0.000000              0.00               0.038462      0.00       0.00
# 2  0.065574              0.00               0.032787      0.00       0.00
# 3  0.000000              0.01               0.000000      0.02       0.01
#
#    Pizza Place     Plaza      Pool   Pub  Public Art  Resort  Restaurant  \
# 0     0.010000  0.000000  0.000000  0.00        0.01    0.00        0.01
# 1     0.000000  0.038462  0.038462  0.00        0.00    0.00        0.00
# 2     0.016393  0.000000  0.000000  0.00        0.00    0.00        0.00
# 3     0.030000  0.010000  0.000000  0.01        0.00    0.01        0.01
#
#    Russian Restaurant  Salad Place  Sandwich Place  Seafood Restaurant  \
# 0                0.01     0.000000         0.00000            0.020000
# 1                0.00     0.000000         0.00000            0.000000
# 2                0.00     0.016393         0.04918            0.032787
# 3                0.00     0.000000         0.04000            0.050000
#
#    Shipping Store  Southern / Soul Food Restaurant  Spanish Restaurant  \
# 0        0.000000                         0.000000                0.00
# 1        0.000000                         0.000000                0.00
# 2        0.016393                         0.032787                0.00
# 3        0.000000                         0.000000                0.01
#
#    Speakeasy  Sports Bar  Steakhouse  Sushi Restaurant  Taco Place  \
# 0       0.04    0.000000    0.040000          0.010000    0.010000
# 1       0.00    0.038462    0.000000          0.000000    0.000000
# 2       0.00    0.000000    0.016393          0.016393    0.016393
# 3       0.00    0.000000    0.040000          0.010000    0.010000
#
#    Thai Restaurant   Theater  Theme Park Ride / Attraction  Theme Restaurant  \
# 0         0.000000  0.010000                      0.000000          0.000000
# 1         0.000000  0.000000                      0.000000          0.000000
# 2         0.016393  0.032787                      0.016393          0.016393
# 3         0.000000  0.030000                      0.000000          0.010000
#
#    Thrift / Vintage Store  Vietnamese Restaurant  Whisky Bar  Wine Bar  \
# 0                    0.00               0.000000        0.01  0.010000
# 1                    0.00               0.000000        0.00  0.000000
# 2                    0.00               0.016393        0.00  0.016393
# 3                    0.01               0.000000        0.00  0.010000
#
#    Yoga Studio
# 0         0.01
# 1         0.00
# 2         0.00
# 3         0.00

# %% [markdown]
# ## Get 10 Most Common Values for Each City

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

##########################################################################

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
city_venues_most = pd.DataFrame(columns=columns)
city_venues_most['City'] = city_grouped['City']

for ind in np.arange(city_grouped.shape[0]):
    city_venues_most.iloc[ind, 1:] = return_most_common_venues(city_grouped.iloc[ind, :], num_top_venues)

city_venues_most.head()
# Out:
#           City 1st Most Common Venue 2nd Most Common Venue  \
# 0       Austin                 Hotel                   Bar
# 1       Dallas                 Hotel           Coffee Shop
# 2      Houston           Coffee Shop                  Park
# 3  San Antonio                 Hotel    Mexican Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0           Coffee Shop          Cocktail Bar               Gay Bar
# 1                  Café              Boutique      Department Store
# 2                 Hotel        Sandwich Place          Burger Joint
# 3          Cocktail Bar    Seafood Restaurant   American Restaurant
#
#    6th Most Common Venue 7th Most Common Venue     8th Most Common Venue  \
# 0             Steakhouse             Speakeasy                Food Truck
# 1  Performing Arts Venue                 Plaza                      Pool
# 2  Performing Arts Venue    Seafood Restaurant  Mediterranean Restaurant
# 3         Sandwich Place            Steakhouse               Pizza Place
#
#   9th Most Common Venue   10th Most Common Venue
# 0                Lounge  New American Restaurant
# 1     Mobile Phone Shop       Mexican Restaurant
# 2               Theater             Concert Hall
# 3                   Bar              Coffee Shop

# %% [markdown]
# ## Get 10 Least Common Values for Each City

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=True)
    
    return row_categories_sorted.index.values[0:num_top_venues]

##########################################################################

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Least Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Least Common Venue'.format(ind+1))

# create a new dataframe
city_venues_least = pd.DataFrame(columns=columns)
city_venues_least['City'] = city_grouped['City']

for ind in np.arange(city_grouped.shape[0]):
    city_venues_least.iloc[ind, 1:] = return_most_common_venues(city_grouped.iloc[ind, :], num_top_venues)

city_venues_least.head()
# Out:
#           City 1st Least Common Venue  2nd Least Common Venue  \
# 0       Austin        Airport Service  Furniture / Home Store
# 1       Dallas        Airport Service                Pharmacy
# 2      Houston            Yoga Studio              Food Truck
# 3  San Antonio        Airport Service       Mobile Phone Shop
#
#       3rd Least Common Venue  4th Least Common Venue 5th Least Common Venue  \
# 0           Greek Restaurant           Grocery Store          Historic Site
# 1           Pedestrian Plaza                    Park  Outdoors & Recreation
# 2          French Restaurant  Furniture / Home Store                Gay Bar
# 3  Latin American Restaurant               Juice Bar              Jazz Club
#
#   6th Least Common Venue 7th Least Common Venue 8th Least Common Venue  \
# 0         History Museum         Ice Cream Shop      Indian Restaurant
# 1              Nightclub           Neighborhood            Music Venue
# 2              Gift Shop       Greek Restaurant          Grocery Store
# 3    Japanese Restaurant     Israeli Restaurant          Movie Theater
#
#   9th Least Common Venue 10th Least Common Venue
# 0    Japanese Restaurant       Mobile Phone Shop
# 1                 Museum           Movie Theater
# 2     Russian Restaurant           Historic Site
# 3      Indian Restaurant                     Gym

# %% [markdown]
# ### Let's take a look on the most and least venues in each city

# %%
city_top_bot_merge = city_venues_most.merge(city_venues_least, on='City',how='left')

# %%
city_topbot = city_top_bot_merge.transpose()[:]
city_topbot.columns = list(city_topbot.iloc[0,:])
city_topbot = city_topbot.drop('City', axis=0).reset_index()

# %%
city_topbot['type'] = np.where(city_topbot['index'].str.contains('Most'), 'most', 'least')

# %%
city_topbot
# Out:
#                       index                   Austin                 Dallas  \
# 0     1st Most Common Venue                    Hotel                  Hotel
# 1     2nd Most Common Venue                      Bar            Coffee Shop
# 2     3rd Most Common Venue              Coffee Shop                   Café
# 3     4th Most Common Venue             Cocktail Bar               Boutique
# 4     5th Most Common Venue                  Gay Bar       Department Store
# 5     6th Most Common Venue               Steakhouse  Performing Arts Venue
# 6     7th Most Common Venue                Speakeasy                  Plaza
# 7     8th Most Common Venue               Food Truck                   Pool
# 8     9th Most Common Venue                   Lounge      Mobile Phone Shop
# 9    10th Most Common Venue  New American Restaurant     Mexican Restaurant
# 10   1st Least Common Venue          Airport Service        Airport Service
# 11   2nd Least Common Venue   Furniture / Home Store               Pharmacy
# 12   3rd Least Common Venue         Greek Restaurant       Pedestrian Plaza
# 13   4th Least Common Venue            Grocery Store                   Park
# 14   5th Least Common Venue            Historic Site  Outdoors & Recreation
# 15   6th Least Common Venue           History Museum              Nightclub
# 16   7th Least Common Venue           Ice Cream Shop           Neighborhood
# 17   8th Least Common Venue        Indian Restaurant            Music Venue
# 18   9th Least Common Venue      Japanese Restaurant                 Museum
# 19  10th Least Common Venue        Mobile Phone Shop          Movie Theater
#
#                      Houston                San Antonio   type
# 0                Coffee Shop                      Hotel   most
# 1                       Park         Mexican Restaurant   most
# 2                      Hotel               Cocktail Bar   most
# 3             Sandwich Place         Seafood Restaurant   most
# 4               Burger Joint        American Restaurant   most
# 5      Performing Arts Venue             Sandwich Place   most
# 6         Seafood Restaurant                 Steakhouse   most
# 7   Mediterranean Restaurant                Pizza Place   most
# 8                    Theater                        Bar   most
# 9               Concert Hall                Coffee Shop   most
# 10               Yoga Studio            Airport Service  least
# 11                Food Truck          Mobile Phone Shop  least
# 12         French Restaurant  Latin American Restaurant  least
# 13    Furniture / Home Store                  Juice Bar  least
# 14                   Gay Bar                  Jazz Club  least
# 15                 Gift Shop        Japanese Restaurant  least
# 16          Greek Restaurant         Israeli Restaurant  least
# 17             Grocery Store              Movie Theater  least
# 18        Russian Restaurant          Indian Restaurant  least
# 19             Historic Site                        Gym  least

# %%
city_most = city_venues_most.transpose()[:]
city_most.columns = list(city_most.iloc[0,:])
city_most = city_most.drop('City', axis=0).reset_index(drop=True)

# %%
city_most.reset_index(inplace=True)
city_most['place'] = city_most['index']+1

# %%
city_most.drop('index',axis=1,inplace=True)

# %%
city_most
# Out:
#                     Austin                 Dallas                   Houston  \
# 0                    Hotel                  Hotel               Coffee Shop
# 1                      Bar            Coffee Shop                      Park
# 2              Coffee Shop                   Café                     Hotel
# 3             Cocktail Bar               Boutique            Sandwich Place
# 4                  Gay Bar       Department Store              Burger Joint
# 5               Steakhouse  Performing Arts Venue     Performing Arts Venue
# 6                Speakeasy                  Plaza        Seafood Restaurant
# 7               Food Truck                   Pool  Mediterranean Restaurant
# 8                   Lounge      Mobile Phone Shop                   Theater
# 9  New American Restaurant     Mexican Restaurant              Concert Hall
#
#            San Antonio  place
# 0                Hotel      1
# 1   Mexican Restaurant      2
# 2         Cocktail Bar      3
# 3   Seafood Restaurant      4
# 4  American Restaurant      5
# 5       Sandwich Place      6
# 6           Steakhouse      7
# 7          Pizza Place      8
# 8                  Bar      9
# 9          Coffee Shop     10

# %% [markdown]
# Looking at the top 10 most venues on each of the cities, we see that Coffee Shop is top 3 for Austin, Dallas, Houston but # 10 in San Antonio, this may point that the Coffee Shop market is up and coming in San Antonio and has not yet been over saturated.

# %%
city_most.to_csv('C:/Users/eadame/Documents/Learning/IBM Data Science Cert/Capstone Project/city_most.csv')

# %%
city_topbot.to_csv('C:/Users/eadame/Documents/Learning/IBM Data Science Cert/Capstone Project/city_most_least.csv')
